# %% [markdown]
# <a href="https://colab.research.google.com/github/Run3M4g3/csc603/blob/main/Colab_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Colab Tutorial
#
#
# This notebook covers runtime setup, shortcuts, data handling, Drive/GitHub integration, bash commands, and more.

# %% [markdown]
# ## 1) Overview
# - Cloud-hosted Python environment.
# - Cells: Code or Markdown.
# - Runtime is ephemeral (resets when disconnected).
# - `/content` = temporary folder.
# - Save to Google Drive/GitHub for persistence.

# %% [markdown]
# ## helllo

# %%
print("hello")
# Out:
# hello

# %%
print("hello")
# Out:
# hello

# %%
# !pip install tqdm

# %%
import time
from tqdm import tqdm
for i in tqdm(range(100)):
  time.sleep(1)
  print(i)
# Out:
#   1%|          | 1/100 [00:01<01:39,  1.00s/it]
# 0
#   2%|▏         | 2/100 [00:02<01:38,  1.00s/it]
# 1
#   3%|▎         | 3/100 [00:03<01:37,  1.00s/it]
# 2
#   4%|▍         | 4/100 [00:04<01:36,  1.00s/it]
# 3
#   5%|▌         | 5/100 [00:05<01:35,  1.00s/it]
# 4
#   6%|▌         | 6/100 [00:06<01:34,  1.00s/it]
# 5
#   7%|▋         | 7/100 [00:07<01:33,  1.00s/it]
# 6
#   8%|▊         | 8/100 [00:08<01:32,  1.00s/it]
# 7
#   9%|▉         | 9/100 [00:09<01:31,  1.00s/it]
# 8
#  10%|█         | 10/100 [00:10<01:30,  1.00s/it]
# 9
#  11%|█         | 11/100 [00:11<01:29,  1.00s/it]
# 10
#  12%|█▏        | 12/100 [00:12<01:28,  1.00s/it]
# 11
#  13%|█▎        | 13/100 [00:13<01:27,  1.00s/it]
# 12
#  14%|█▍        | 14/100 [00:14<01:26,  1.00s/it]
# 13
#  15%|█▌        | 15/100 [00:15<01:25,  1.00s/it]
# 14
#  16%|█▌        | 16/100 [00:16<01:24,  1.00s/it]
# 15
#  17%|█▋        | 17/100 [00:17<01:23,  1.00s/it]
# 16
#  18%|█▊        | 18/100 [00:18<01:22,  1.00s/it]
# 17
# ...

# %%
# !ls
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ## 2) Changing the Runtime
# Runtime ▸ Change runtime type ▸ Select GPU/TPU/CPU.

# %% [markdown]
# ## 3) Keyboard Shortcuts
# - Run cell: Shift+Enter
# - Run cell and create new cell below: Alt+Enter
# - Insert cell above/below: Ctrl+M+A / Ctrl+M+B
# - Delete cell: Ctrl+M+D (twice)
# - Interrupt: Ctrl+M+I
# - Restart: Ctrl+M+.

# %% [markdown]
# ## 4) Uploading Data
# ```python
# from google.colab import files
# uploaded = files.upload()
# list(uploaded.keys())
# ```
# ```python
# files.download('/content/example.csv')
# ```

# %% [markdown]
# ## 5) Mount Google Drive
# ```python
# from google.colab import drive
# drive.mount('/content/drive')
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 6) Connect to GitHub
# - Clone public repo: `!git clone https://github.com/user/repo.git`
# - Private repo: use Personal Access Token (PAT).

# %% [markdown]
# ## 7) Bash Commands
# ```python
# !pwd
# !ls -la | head -n 5
# ```
# ```bash
# %%bash
# echo "Hello from bash"
# python -V
# ```

# %% [markdown]
# ## 8) Installing Packages
# `!pip install transformers datasets`

# %% [markdown]
# /content/sample_data/california_housing_test.csv

# %% [markdown]
# ## 9) Files & Paths
# - Temp: `/content`
# - Drive: `/content/drive/MyDrive`
# ```python
# with open('/content/demo.txt','w') as f: f.write('hello')
# print(open('/content/demo.txt').read())
#
#
# ```

# %% [markdown]
# ## 10) Pandas Display
# ```python
# import pandas as pd
# df = pd.DataFrame({'a':[1,2], 'b':[3,4]})
# df
# ```

# %% [markdown]
# ## 11) Forms
# ```python
# #@title Greeter
# name = "World" #@param {type:"string"}
# print(f"Hello {name}")
# ```

# %% [markdown]
# ## 12) Best Practices
# - Save work to Drive.
# - Restart if memory issues.
# - Avoid storing secrets.
# - Checkpoints: File ▸ Save a copy in Drive.

# %% [markdown]
# Google colab tutorial link
# https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb
#
# https://colab.research.google.com/
